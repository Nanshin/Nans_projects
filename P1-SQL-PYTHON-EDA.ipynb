# %%
# !pip install mysql connector.python
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000017A7F091308>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/mysql/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000017A7F091488>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/mysql/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000017A7F339448>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/mysql/
# ...

# %%
import mysql.connector

# %%
import pandas as pd
con= mysql.connector.connect(
     host = '127.0.0.1',
     user = 'root',
     password = 'Jesus247',
     database = 'project1')
print(con)
df=pd.read_sql_query("Select * from studmarks",con)
df
df.head(10)
# Out:
# ...
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df.shape
# Out:
# (10, 11)

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Gender     10 non-null     object
#  2   DOB        10 non-null     object
#  3   Maths      10 non-null     int64
#  4   Physics    10 non-null     int64
#  5   Chemistry  10 non-null     int64
#  6   English    10 non-null     int64
#  7   Biology    10 non-null     int64
#  8   Economics  10 non-null     int64
#  9   History    10 non-null     int64
#  10  Civics     10 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %%
df.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfcor=df.corr()
dfcor
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Maths     -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
sns.heatmap(dfcor, annot=True)#none of the attributes depend on each other

# %%
sns.heatmap(df.isnull())

# %%
sns.countplot(df['Gender'])# an equal spread of students gender

# %%
sns.countplot(df['DOB'])an equal spread of students DOB

# %%
df['Maths'].plot.bar()

# %%
df['Physics'].plot.bar()

# %%
df['Chemistry'].plot.hist()

# %%
df['Biology'].plot.hist()

# %%
df['Economics'].plot.box()

# %%
df['History'].plot.box()

# %%
df['Civics'].plot.box()

# %%
df.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# Maths           AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Physics      AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Chemistry     AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# English      AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Biology      AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Economics          AxesSubplot(0.125,0.125;0.133621x0.343182)
# History         AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Civics           AxesSubplot(0.44569,0.125;0.133621x0.343182)
# dtype: object

# %%
sns.lineplot(x='Maths',y='English',data=df)

# %%
z=sns.catplot(x='Maths',y='English',hue='Gender',data=df, kind='bar')
plt.show()

# %%
z=sns.catplot(x='Physics',y='Chemistry',hue='Gender',data=df, kind='bar')
plt.show()

# %%
z=sns.catplot(x='History',y='Economics',hue='Gender',data=df, kind='bar')
plt.show()

# %%
plt.scatter(df['Maths'],df['English'])

# %%
z=sns.catplot(x='Maths',y='English',hue='DOB',data=df, kind='bar')
plt.show()

# %%
sns.set(style="whitegrid")
ax=sns.stripplot(x='Physics',y='Chemistry',data=df);
plt.title('Graph')
plt.show()

# %%
sns.pairplot(df)

# %%
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.shape
# Out:
# (10, 10)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df['DOB']=(pd.to_datetime(df['DOB'].str.strip(), errors='coerce').dt.strftime('%YY-%MM-%DD'))

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
df.dtypes
# Out:
# Gender                int32
# DOB          datetime64[ns]
# Maths                 int64
# Physics               int64
# Chemistry             int64
# English               int64
# Biology               int64
# Economics             int64
# History               int64
# Civics                int64
# dtype: object

# %%
df_deep_copy = df

# %%
df.drop('DOB',axis=1,inplace=True)

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
# Out:
# (10, 9)
# (10, 9)

# %% [raw]
# Conclusion:Dataset had no missing values and distribution seem to be normal. while Biology and Economics subjects seemed to be the most strongly positive related subjects, Economics and Maths seem to be the worst strongly negative related subjects. Females tend to perform better in the Maths subject. The least performed subject is Maths followed by Biology while the best performed subject is Chemistry. Civics has an outlier value of 2.00. Also the gender spread of students seem to be equal.
