# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Skyserver.csv')

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
nan_df=df[df.isna().any(axis=1)]
nan_df.head()
# Out:
# Empty DataFrame
# Columns: [objid, ra, dec, u, g, r, i, z, run, rerun, camcol, field, specobjid, class, redshift, plate, mjd, fiberid]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])

# %%
sns.heatmap(df)

# %%
dfcor=df.corr()
dfcor
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %%
sns.heatmap(dfcor)

# %%
sns.heatmap(df.isnull())

# %%
sns.heatmap(dfcor,cmap="Blues",annot=True)

# %%
df['plate'].plot.hist()

# %%
df['field'].plot.hist()

# %%
df['class'].plot.bar()

# %%
df['fiberid'].plot.box()#outliers exist here

# %%
sns.lineplot(x='field',y='ra',data=df)
plt.show()

# %%
plt.scatter(df['fiberid'],df['camcol'])
plt.show()

# %%
plt.scatter(df['specobjid'],df['plate'])
plt.show()#strong positive relationship exist here

# %%
collist=df.columns.values
ncol=18
nrows=4

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()#outliers exists

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# objid        0.000000e+00
# ra           4.417633e+01
# dec          3.618843e+01
# u            1.081197e+00
# g            1.195045e+00
# r            1.339343e+00
# i            1.404845e+00
# z            1.523162e+00
# run          5.790000e+02
# rerun        0.000000e+00
# camcol       3.000000e+00
# field        2.300000e+02
# specobjid    2.542375e+18
# class        2.000000e+00
# redshift     9.249761e-02
# plate        2.258000e+03
# mjd          2.568000e+03
# fiberid      3.232500e+02
# dtype: float64

# %%
df_out=df[~((df<(Q1 - 1.5 * IQR)) | (df>(Q3 + 1.5 * IQR))).any(axis=1)]
df_out.shape# outliers are out
# Out:
# (7978, 18)

# %%
df_out.skew()
# Out:
# objid        1.000188
# ra           0.237568
# dec          1.262652
# u           -0.845928
# g           -0.577114
# r           -0.276244
# i           -0.104173
# z            0.024907
# run          0.570086
# rerun        0.000000
# camcol      -0.129838
# field        0.172718
# specobjid    1.042591
# class        0.354981
# redshift     0.608667
# plate        1.042584
# mjd          0.915484
# fiberid      0.068206
# dtype: float64

# %%
objid_sqrt=np.sqrt(df_out['objid'])
objid_sqrt.skew()
# Out:
# 0.0

# %%
dec_sqrt=np.sqrt(df_out['dec'])
dec_sqrt.skew()
# Out:
# 0.36740604966793133

# %%
run_sqrt=np.sqrt(df_out['run'])
run_sqrt.skew()
# Out:
# 0.5238055584493175

# %%
specobjid_sqrt=np.sqrt(df_out['specobjid'])
specobjid_sqrt.skew()
# Out:
# 0.8855497189909499

# %%
redshift_sqrt=np.sqrt(df_out['redshift'])
redshift_sqrt.skew()
# Out:
# -0.42538402604101927

# %%
plate_sqrt=np.sqrt(df_out['plate'])
plate_sqrt.skew()
# Out:
# 0.8855393512114947

# %%
mjd_sqrt=np.sqrt(df_out['mjd'])
mjd_sqrt.skew()
# Out:
# 0.9104909241458974

# %% [raw]
# Obseravtions:

# %%
cols=list(df_out.columns.values)
cols.pop(cols.index('class'))
df_out=df_out[cols+['class']]

# %%
df_out.head(3)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
#
#           z  run  rerun  camcol  field     specobjid  redshift  plate    mjd  \
# 0  15.22531  752    301       4    267  3.722360e+18 -0.000009   3306  54922
# 1  16.39150  752    301       4    267  3.638140e+17 -0.000055    323  51615
# 2  16.80125  752    301       4    268  3.232740e+17  0.123111    287  52023
#
#    fiberid  class
# 0      491      2
# 1      541      2
# 2      513      0

# %%
#seperating my input and output variables
x=df_out.iloc[:,0:-1]
x.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid  redshift  plate    mjd  \
# 0  15.22531  752    301       4    267  3.722360e+18 -0.000009   3306  54922
# 1  16.39150  752    301       4    267  3.638140e+17 -0.000055    323  51615
# 2  16.80125  752    301       4    268  3.232740e+17  0.123111    287  52023
# 3  15.90438  752    301       4    269  3.722370e+18 -0.000111   3306  54922
# 4  16.61326  752    301       4    269  3.722370e+18  0.000590   3306  54922
#
#    fiberid
# 0      491
# ...

# %%
y=pd.DataFrame(df_out['class'])
y.head()
# Out:
#    class
# 0      2
# 1      2
# 2      0
# 3      2
# 4      2

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_out)
x=pd.DataFrame(x,columns=df_out.columns)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=9,stratify=y)

# %%
x_train.shape,x_test.shape
# Out:
# ((5584, 18), (2394, 18))

# %%
y_train.shape,y_test.shape
# Out:
# ((5584, 1), (2394, 1))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
SV=SVC()
DT=DecisionTreeClassifier(random_state=6)
GNB=GaussianNB()

# %%
models = []
models.append(('KNeighborsClassifier', KNN))
models.append(('SVC', SV))
models.append(('DecisionTreeClassifier', DT))
models.append(('GaussianNB', GNB))

# %%
Model = []
score = []
cvs = []
rocscore =[]
for name,model in models:
    print('***********************',name,'***********************')
    print('\n')
    print(model)
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score= ',AS)
    score.append(AS*100)
    print('\n')
    sc = cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score= ',sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre), end = "\n\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'r--')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# *********************** KNeighborsClassifier ***********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
#
#
# Accuracy_score=  0.9891395154553049
#
#
# Cross_Val_Score=  0.988218350141351
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1398
#            1       1.00      0.18      0.30        17
#            2       0.99      0.99      0.99       979
#
#     accuracy                           0.99      2394
#    macro avg       0.99      0.72      0.76      2394
# weighted avg       0.99      0.99      0.99      2394
#
#
# [[1391    0    7]
# ...

# %%
result=pd.DataFrame({'Model':Model, 'Accuracy_score': score,'Cross_val_score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score
# 0    KNeighborsClassifier       98.913952        98.821835
# 1                     SVC       99.916458        99.949859
# 2  DecisionTreeClassifier      100.000000       100.000000
# 3              GaussianNB      100.000000       100.000000

# %%
from sklearn.externals import joblib

# %%
joblib.dump(DT,'skyserver_predfile.obj')
# Out:
# ['skyserver_predfile.obj']

# %% [raw]
# Conclusion: DecisionTreeClassifier and GaussianNB performed best with Accuracy_score=100%, Cross_val_score=100%. Roc_auc_curve could not be applied because the dataset is multi-class. This implies the model is able to accurately predict whether the object cited in space is a star, galaxy or quasar, if given the above attributes. The model is saved for future use.
