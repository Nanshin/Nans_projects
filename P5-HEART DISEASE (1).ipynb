# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('heartdisease.csv')

# %%
df.head()
# Out:
#    63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0  44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1  60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2  55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3  66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4  66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (199, 14)

# %%
df.columns
# Out:
# Index(['63', '1', '4', '140', '260', '0', '1.1', '112', '1.2', '3', '2', '?',
#        '?.1', '2.1'],
#       dtype='object')

# %%
df.rename({'63':'age', '1':'sex', '4':'cp', '140':'trestbps', '260':'chol', '0':'fbs', '1.1':'restecg', '112':'thalach', '1.2':'exang', '3':'oldpeak', '2':'slope', '?':'ca',
       '?.1':'thal', '2.1':'num'}, axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   44    1   4      130  209   0        1     127     0       0     ?  ?
# 1   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3   66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4   66    1   3      120    0   0        1     120     0    -0.5     1  ?
#
#   thal  num
# 0    ?    0
# 1    ?    2
# 2    ?    1
# 3    ?    0
# 4    ?    0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  199 non-null    object
#  4   chol      199 non-null    object
#  5   fbs       199 non-null    object
#  6   restecg   199 non-null    int64
#  7   thalach   199 non-null    object
#  8   exang     199 non-null    object
#  9   oldpeak   199 non-null    object
#  10  slope     199 non-null    object
#  11  ca        199 non-null    object
#  12  thal      199 non-null    object
#  13  num       199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df.describe()
# Out:
#               age         sex          cp     restecg         num
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513    0.733668    1.517588
# std      7.827080    0.171433    0.796928    0.684918    1.222038
# min     35.000000    0.000000    1.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000    1.000000    1.000000
# 75%     64.000000    1.000000    4.000000    1.000000    3.000000
# max     77.000000    1.000000    4.000000    2.000000    4.000000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.isna().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# num         False
# dtype: bool

# %%
df.replace('?', np.nan,inplace=True)

# %%
df.isna().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps     True
# chol         True
# fbs          True
# restecg     False
# thalach      True
# exang        True
# oldpeak      True
# slope        True
# ca           True
# thal         True
# num         False
# dtype: bool

# %%
df.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope   ca  \
# 0   44    1   4      130  209   0        1     127     0       0   NaN  NaN
# 1   60    1   4      132  218   0        1     140     1     1.5     3  NaN
# 2   55    1   4      142  228   0        1     149     1     2.5     1  NaN
# 3   66    1   3      110  213   1        2      99     1     1.3     2  NaN
# 4   66    1   3      120    0   0        1     120     0    -0.5     1  NaN
#
#   thal  num
# 0  NaN    0
# 1  NaN    2
# 2  NaN    1
# 3  NaN    0
# 4  NaN    0

# %%
df.drop('ca',axis=1,inplace=True)

# %%
df.drop('thal',axis=1,inplace=True)

# %%
df_deep_copy=df

# %%
df["trestbps"] = pd.to_numeric(df["trestbps"], errors =  'coerce')

# %%
mean=df['trestbps'].mean()
mean
# Out:
# 133.72027972027973

# %%
df['trestbps'].fillna(mean,inplace=True)

# %%
df["chol"] = pd.to_numeric(df["chol"], errors =  'coerce')

# %%
mean=df['chol'].mean()
mean
# Out:
# 178.32291666666666

# %%
df['chol'].fillna(mean,inplace=True)

# %%
df["fbs"] = pd.to_numeric(df["fbs"], errors =  'coerce')

# %%
mean=df['fbs'].mean()
mean
# Out:
# 0.3541666666666667

# %%
df['fbs'].fillna(mean,inplace=True)

# %%
df["thalach"] = pd.to_numeric(df["thalach"], errors =  'coerce')

# %%
mean=df['thalach'].mean()
mean
# Out:
# 122.86986301369863

# %%
df['thalach'].fillna(mean,inplace=True)

# %%
df["exang"] = pd.to_numeric(df["exang"], errors =  'coerce')

# %%
mean=df['exang'].mean()
mean
# Out:
# 0.6438356164383562

# %%
df['exang'].fillna(mean,inplace=True)

# %%
df["oldpeak"] = pd.to_numeric(df["oldpeak"], errors =  'coerce')

# %%
mean=df['oldpeak'].mean()
mean
# Out:
# 1.309090909090909

# %%
df['oldpeak'].fillna(mean,inplace=True)

# %%
df["slope"] = pd.to_numeric(df["slope"], errors =  'coerce')

# %%
mean=df['slope'].mean()
mean
# Out:
# 2.134020618556701

# %%
df['slope'].fillna(mean,inplace=True)

# %%
df.isna().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# num         False
# dtype: bool

# %%
sns.heatmap(df)

# %%
dfcor=df.corr()
dfcor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.033837 -0.039809  0.180915  0.065347  0.126706
# sex       0.033837  1.000000  0.037525  0.012238 -0.096953 -0.054735
# cp       -0.039809  0.037525  1.000000  0.073888  0.063650 -0.045135
# trestbps  0.180915  0.012238  0.073888  1.000000  0.149121  0.186111
# chol      0.065347 -0.096953  0.063650  0.149121  1.000000  0.154537
# fbs       0.126706 -0.054735 -0.045135  0.186111  0.154537  1.000000
# restecg   0.001487  0.060305  0.033617  0.091401  0.022824  0.167662
# thalach  -0.148786 -0.001016 -0.122405 -0.012047 -0.039052  0.049509
# exang     0.133318  0.015703  0.180299  0.219314  0.084179 -0.210867
# oldpeak   0.154215  0.096219  0.036454  0.113345 -0.005121 -0.093830
# slope     0.100705  0.088371  0.029214  0.092285  0.059860  0.015394
# num       0.286630  0.147190  0.167202  0.141186  0.075094  0.052104
#
#            restecg   thalach     exang   oldpeak     slope       num
# ...

# %%
sns.heatmap(dfcor,annot=True)

# %%
df['age'].plot.box()#outliers exist here

# %%
df['trestbps'].plot.bar()

# %%
df['restecg'].plot.hist()

# %%
sns.countplot(df['sex'])# data mostly consist of the female gender

# %%
sns.countplot(df['num'])#there are more of the type one(1) and less of the type four(4) heart disease category

# %%
plt.scatter(df['trestbps'],df['sex'])
plt.show()

# %%
plt.scatter(df['sex'],df['thalach'])
plt.show()

# %%
collist=df.columns.values
ncol=12
nrows=2

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()#outliers exists

# %%
sns.pairplot(df)

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
# Out:
# (199, 12)
# (180, 12)

# %%
df_new.skew()
# Out:
# age        -0.333875
# sex         0.000000
# cp         -1.405681
# trestbps    0.523528
# chol       -0.537272
# fbs         0.686474
# restecg     0.391614
# thalach    -0.075758
# exang      -0.793250
# oldpeak     0.464049
# slope      -0.170577
# num         0.280466
# dtype: float64

# %%
fbs_sqrt=np.sqrt(df_new['fbs'])
fbs_sqrt.skew()
# Out:
# 0.6207570332690544

# %% [raw]
# Observations:Dataset had missing (NaN) values which were removed and replaced with the mean of the attributes respectively. outliers were also removed using the Zscore and skewed distribution was treated. Hence the data is clean for the modelling stage.

# %%
#seperating my input and output variables
x=df_new.iloc[:,0:-1]
x.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1   60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2   55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3   66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4   66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
#
#       slope
# 0  2.134021
# 1  3.000000
# 2  1.000000
# 3  2.000000
# 4  1.000000

# %%
y=pd.DataFrame(df_new['num'])
y.head()
# Out:
#    num
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_new)
x=pd.DataFrame(x,columns=df_new.columns)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=86,stratify=y)

# %%
x_train.shape,x_test.shape
# Out:
# ((126, 12), (54, 12))

# %%
y_train.shape,y_test.shape
# Out:
# ((126, 1), (54, 1))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
SV=SVC()
DT=DecisionTreeClassifier(random_state=6)
GNB=GaussianNB()

# %%
models = []
models.append(('KNeighborsClassifier', KNN))
models.append(('SVC', SV))
models.append(('DecisionTreeClassifier', DT))
models.append(('GaussianNB', GNB))

# %%
Model = []
score = []
cvs = []
rocscore =[]
for name,model in models:
    print('***********************',name,'***********************')
    print('\n')
    print(model)
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score= ',AS)
    score.append(AS*100)
    print('\n')
    sc = cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score= ',sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre), end = "\n\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'r--')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# *********************** KNeighborsClassifier ***********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
#
#
# Accuracy_score=  0.48148148148148145
#
#
# Cross_Val_Score=  0.5666666666666668
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        13
#            1       0.39      0.44      0.41        16
#            2       0.36      0.36      0.36        11
#            3       0.62      0.45      0.53        11
#            4       1.00      0.33      0.50         3
#
#     accuracy                           0.48        54
# ...

# %%
result=pd.DataFrame({'Model':Model, 'Accuracy_score': score,'Cross_val_score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score
# 0    KNeighborsClassifier       48.148148        56.666667
# 1                     SVC       74.074074        79.444444
# 2  DecisionTreeClassifier      100.000000       100.000000
# 3              GaussianNB      100.000000       100.000000

# %%
from sklearn.externals import joblib

# %%
joblib.dump(DT,'heartdisease_file.obj')
# Out:
# ['heartdisease_file.obj']

# %% [raw]
# Conclusion:DecisionTreeClassifier and GaussianNB performed best with Accuracy_score=100%, Cross_val_score=100%. This implies the model is able to accurately predict whether a person has heart disease or not, and what stage of the disease is present if given the above attributes. The model is saved for future use.
