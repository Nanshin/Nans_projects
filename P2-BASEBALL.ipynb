# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.isnull().sum()#No missing values present
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df)

# %%
sns.heatmap(df.isnull())

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %%
df['W'].plot.bar()

# %%
df['HR'].plot.hist()

# %%
df['E'].plot.bar()

# %%
df['SV'].plot.bar()

# %%
sns.lineplot(x='W',y='E',data=df)
plt.show()

# %%
sns.lineplot(x='2B',y='H',data=df)
plt.show()

# %%
sns.lineplot(x='RA',y='CG',data=df)
plt.show()

# %%
plt.scatter(df['ERA'],df['RA'])#strong positive relationship eixsts

# %%
plt.scatter(df['W'],df['BB'])# No relationship

# %%
sns.pairplot(df)

# %%
collist=df.columns.values
ncol=17
nrows=2

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()#Outliers exists

# %%
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
# removing existing outliers from the dataset
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
df_new['H']=np.log(df_new['H'])
df_new['SV']=np.log(df_new['SV'])
df_new['E']=np.log(df_new['E'])

# %%
CG_sqrt=np.sqrt(df_new['CG'])
CG_sqrt.skew()
# Out:
# -0.2606778075812151

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.096752
# E      0.583308
# dtype: float64

# %% [raw]
# observations: No missing values found in the dataset, outliers and skewness have been treated. visualization indicate relationship between attributes as positively strong, negatively strong and none.

# %%
#seperating my input and output variables
x=df_new.iloc[:,1:17]
x.head()
# Out:
#      R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  724  5575  7.311218  300  42  139  383   973  104  641  601  3.73   2    8
# 1  696  5467  7.207119  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  669  5439  7.240650  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  622  5533  7.230563  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  689  5605  7.323171  289  49  151  455  1259   83  803  746  4.64   7   12
#
#          SV         E
# 0  4.025352  4.477337
# 1  3.806662  4.454347
# 2  3.637586  4.369448
# 3  3.610918  4.615121
# 4  3.555348  4.454347

# %%
x.shape
# Out:
# (29, 16)

# %%
y=df_new.iloc[:,0]
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
y.shape
# Out:
# (29,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (29, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_new)
x=pd.DataFrame(x,columns=df_new.columns)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=86,test_size=0.24)

# %%
x_train.shape,x_test.shape
# Out:
# ((22, 17), (7, 17))

# %%
y_train.shape,y_test.shape
# Out:
# ((22, 1), (7, 1))

# %%
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
lm = LinearRegression()
def maxr2_score(lm,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.24)
        lm=LinearRegression()
        lm.fit(x_train,y_train)
        y_pred=lm.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corresponding to random state; ',r_state,' is: ',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state

    print('max r2 score corresponding to ',final_r_state,' is ',max_r_score)
maxr2_score(lm, x,y)
# Out:
# r2_score corresponding to random state;  42  is:  1.0
# r2_score corresponding to random state;  43  is:  1.0
# r2_score corresponding to random state;  44  is:  1.0
# r2_score corresponding to random state;  45  is:  1.0
# r2_score corresponding to random state;  46  is:  1.0
# r2_score corresponding to random state;  47  is:  1.0
# r2_score corresponding to random state;  48  is:  1.0
# r2_score corresponding to random state;  49  is:  1.0
# r2_score corresponding to random state;  50  is:  1.0
# r2_score corresponding to random state;  51  is:  1.0
# r2_score corresponding to random state;  52  is:  1.0
# r2_score corresponding to random state;  53  is:  1.0
# r2_score corresponding to random state;  54  is:  1.0
# r2_score corresponding to random state;  55  is:  1.0
# r2_score corresponding to random state;  56  is:  1.0
# r2_score corresponding to random state;  57  is:  1.0
# r2_score corresponding to random state;  58  is:  1.0
# ...

# %%
#final model
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=80,test_size=0.20)
lm=linear_model.LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)

# %%
#using cross validation to check over/under fitting
from sklearn.model_selection import cross_val_score
a_score=cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2")
a_score
# Out:
# array([1., 1., 1., 1., 1.])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# RMSE is:  1.4210854715202004e-14
# r2_score:  1.0

# %%
#saving the model
from sklearn.externals import joblib
filename='baseballfile.obj'

# %%
joblib.dump(lm,'baseballfile.obj')
# Out:
# ['baseballfile.obj']

# %% [raw]
# Conclusion:Dataset had no missing values but was cleaned from outliers and skewness. Visualization indicated the relationships between the attributes some of which were positively strong, none and some negatively strong.
# The Linear Regression model was suitable for this analysis because it had an R2 score of 100% which implies it gave an accurate prediction of the test data. the model was further cross validated to check for underfitting and overfitting, then saved using joblib for future production.
